# %% [markdown]
# # Gini

# %% [markdown]
# ## EDA & Cleaning

# %% [markdown]
#     imports

# %%
#terri test text

import numpy as np
import pandas as pd

import missingno as msno

# %% [markdown]
#     read

# %%
loans_df = pd.read_csv("../data/raw/loans.csv")

# %%
key_loan_to_lender_df = pd.read_csv("../data/raw/loans_lenders.csv")

# %%
lenders_df = pd.read_csv("../data/raw//lenders.csv")

# %%
loans_df.iloc[0:5,0:10]
# Out:
#    LOAN_ID    LOAN_NAME ORIGINAL_LANGUAGE  \
# 0  1737446      Emelisa           English
# 1  1274681        Samol           English
# 2  1552694         ABLA            French
# 3  1756537  Emanuellita           English
# 4   343721       Leizel           English
#
#                                          DESCRIPTION  \
# 0  Emelisa is 32 years old.  With two children in...
# 1  Samol is married and she lives with her husban...
# 2  Abla est une femme célibataire qui habite à Ag...
# 3  Emanuellita works hard to support six children...
# 4  Leizel is 26 years old and married with one ch...
#
#                               DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 0  Emelisa is 32 years old.  With two children in...          125.0
# 1  Samol is married and she lives with her husban...         1000.0
# 2  Abla is an unmarried woman living in Agoe. She...          200.0
# 3  Emanuellita works hard to support six children...          100.0
# 4                                                NaN          375.0
#
#    LOAN_AMOUNT  STATUS   IMAGE_ID  VIDEO_ID
# 0        125.0  funded  3120573.0       NaN
# 1       1000.0  funded  2493249.0       NaN
# 2        200.0  funded  2877629.0       NaN
# 3        100.0  funded  3146822.0       NaN
# 4        375.0  funded   883415.0       NaN

# %%
loans_df.iloc[0:5,10:20]
# Out:
#                ACTIVITY_NAME  SECTOR_NAME  \
# 0              General Store       Retail
# 1  Personal Housing Expenses      Housing
# 2      Food Production/Sales         Food
# 3  Personal Housing Expenses      Housing
# 4                  Livestock  Agriculture
#
#                                             LOAN_USE COUNTRY_CODE  \
# 0  to buy items to sell like beverages, canned go...           PH
# 1                 to purchase construction material.           KH
# 2  to buy 5 sacks of corn, 2 cans of oil, and a s...           TG
# 3                         to build a sanitary toilet           PH
# 4                          to buy livestock to raise           PH
#
#   COUNTRY_NAME                      TOWN_NAME CURRENCY_POLICY  \
# 0  Philippines         Calbayog City 2, Samar          shared
# 1     Cambodia             Prek Pnov District        standard
# 2         Togo                           Agoe          shared
# 3  Philippines                  Cordova, Cebu          shared
# 4  Philippines  Kabankalan, Negros Occidental          shared
#
#    CURRENCY_EXCHANGE_COVERAGE_RATE CURRENCY  PARTNER_ID
# 0                              0.1      PHP         145
# 1                              NaN      USD          61
# 2                              0.1      XOF         296
# 3                              0.1      PHP         145
# 4                              0.2      PHP         145

# %%
loans_df.iloc[0:5,20:]
# Out:
#                      POSTED_TIME        PLANNED_EXPIRATION_TIME  \
# 0  2019-04-02 02:35:31.000 +0000  2019-05-17 16:00:46.000 +0000
# 1  2017-04-06 08:05:02.000 +0000  2017-05-14 22:20:02.000 +0000
# 2  2018-06-19 15:54:57.000 +0000  2018-07-20 23:00:08.000 +0000
# 3  2019-05-06 00:59:44.000 +0000  2019-06-16 16:30:10.000 +0000
# 4  2011-10-06 07:45:46.000 +0000                            NaN
#
#                    DISBURSE_TIME                    RAISED_TIME  LENDER_TERM  \
# 0  2019-03-29 07:00:00.000 +0000  2019-04-17 20:35:08.000 +0000          8.0
# 1  2017-03-17 07:00:00.000 +0000  2017-05-11 14:22:45.000 +0000         26.0
# 2  2018-05-24 07:00:00.000 +0000  2018-06-21 01:18:23.000 +0000          9.0
# 3  2019-04-25 07:00:00.000 +0000  2019-05-17 17:31:13.000 +0000         14.0
# 4  2011-09-16 07:00:00.000 +0000  2011-10-13 00:18:57.000 +0000         11.0
#
#    NUM_LENDERS_TOTAL  NUM_JOURNAL_ENTRIES  NUM_BULK_ENTRIES  \
# 0                  4                    1                 1
# 1                 26                    1                 1
# 2                  5                    1                 1
# 3                  4                    2                 1
# 4                 14                    2                 1
#
#                                     TAGS BORROWER_NAMES BORROWER_GENDERS  \
# 0                  #Woman-Owned Business        Emelisa           female
# 1         #Repair Renew Replace, #Parent          Samol           female
# 2   #Woman-Owned Business, user_favorite           ABLA           female
# 3  #Health and Sanitation, #Eco-friendly    Emanuellita           female
# 4                                    NaN         Leizel           female
#
#   BORROWER_PICTURED REPAYMENT_INTERVAL DISTRIBUTION_MODEL
# 0              true            monthly      field_partner
# 1              true            monthly      field_partner
# 2              true            monthly      field_partner
# 3              true            monthly      field_partner
# 4              true            monthly      field_partner

# %%
loans_df.columns
# Out:
# Index(['LOAN_ID', 'LOAN_NAME', 'ORIGINAL_LANGUAGE', 'DESCRIPTION',
#        'DESCRIPTION_TRANSLATED', 'FUNDED_AMOUNT', 'LOAN_AMOUNT', 'STATUS',
#        'IMAGE_ID', 'VIDEO_ID', 'ACTIVITY_NAME', 'SECTOR_NAME', 'LOAN_USE',
#        'COUNTRY_CODE', 'COUNTRY_NAME', 'TOWN_NAME', 'CURRENCY_POLICY',
#        'CURRENCY_EXCHANGE_COVERAGE_RATE', 'CURRENCY', 'PARTNER_ID',
#        'POSTED_TIME', 'PLANNED_EXPIRATION_TIME', 'DISBURSE_TIME',
#        'RAISED_TIME', 'LENDER_TERM', 'NUM_LENDERS_TOTAL',
#        'NUM_JOURNAL_ENTRIES', 'NUM_BULK_ENTRIES', 'TAGS', 'BORROWER_NAMES',
#        'BORROWER_GENDERS', 'BORROWER_PICTURED', 'REPAYMENT_INTERVAL',
#        'DISTRIBUTION_MODEL'],
#       dtype='object')
